# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import ezodf
import matplotlib.patches as mpatches

# %%
file = '/home/jan/Documents/Doktorarbeit/Daten/HOAF_ecg/Physio_combined.ods'

# %%
doc = ezodf.opendoc(file)

print("Spreadsheet contains %d sheet(s)." % len(doc.sheets))
for sheet in doc.sheets:
    print("-"*40)
    print("   Sheet name : '%s'" % sheet.name)
    print("Size of Sheet : (rows=%d, cols=%d)" % (sheet.nrows(), sheet.ncols()) )

# convert the first sheet to a pandas.DataFrame
sheet = doc.sheets[0]
df_dict = {}
for i, row in enumerate(sheet.rows()):
    # row is a list of cells
    # assume the header is on the first row
    if i == 0:
        # columns as lists in a dictionary
        df_dict = {cell.value:[] for cell in row}
        # create index for the column headers
        col_index = {j:cell.value for j, cell in enumerate(row)}
        continue
    for j, cell in enumerate(row):
        # use header instead of column index
        df_dict[col_index[j]].append(cell.value)
# and convert to a DataFrame
df = pd.DataFrame(df_dict)
# Out:
# Spreadsheet contains 1 sheet(s).
# ----------------------------------------
#    Sheet name : 'Sheet1'
# Size of Sheet : (rows=717, cols=91)

# %%
a = pd.DataFrame(df)
a_asndarray = a.values

# %%
extractedData = a.values[:,[0]]
extractedData_2 = a.values[:,[2]]
extractedData_3 = a.values[:,[1]]

# %%
x  =extractedData
y = extractedData_2
z = extractedData_3

fig, ax = plt.subplots()
ax.plot(y, label='stress_2')
ax.plot(x, label='stress_1')

plt.xlabel('Zeit(s)')
plt.ylabel('Puls(bpm)')

plt.title("Pulsdaten Stressblock 1+2")

plt.legend()
plt.gca().axvspan(0,154, facecolor='0.8',alpha = 0.5)
plt.gca().axvspan(182,330, facecolor='0.9',alpha = 0.5)
plt.gca().axvspan(358,506, facecolor='0.8',alpha = 0.5)
plt.gca().axvspan(534,682, facecolor='0.9',alpha = 0.5)
#plt.axvline(100, color='k', linestyle='--')
plt.show()

#save image

fig = plt.figure()

plt.savefig('BLock1_"', dpi=None, facecolor=None, edgecolor=None,
        orientation='portrait', papertype=None, format=None,
        transparent=False, bbox_inches=None, pad_inches=0.1,
        frameon=None, metadata=None)

# %%
plt.plot(x,label="stress_1")
plt.xlabel('Zeit(s)')
plt.ylabel('Puls(bpm)')

plt.title("Pulsdaten Stressblock 1")

plt.legend()
plt.gca().axvspan(0,154, facecolor='0.8',alpha = 0.5)
plt.gca().axvspan(182,330, facecolor='0.9',alpha = 0.5)
plt.gca().axvspan(358,506, facecolor='0.8',alpha = 0.5)
plt.gca().axvspan(534,682, facecolor='0.9',alpha = 0.5)

plt.show()

# %%
plt.plot(y,label="stress_2")
plt.xlabel('Zeit(s)')
plt.ylabel('Puls(bpm)')

plt.title("Pulsdaten Stressblock 2")

plt.legend()
plt.gca().axvspan(0,154, facecolor='0.8',alpha = 0.5)
plt.gca().axvspan(182,330, facecolor='0.9',alpha = 0.5)
plt.gca().axvspan(358,506, facecolor='0.8',alpha = 0.5)
plt.gca().axvspan(534,682, facecolor='0.9',alpha = 0.5)
plt.show()

# %%
plt.plot(z,label="music/sound")
plt.xlabel('Zeit(s)')
plt.ylabel('Puls(bpm)')

plt.title("Pulsdaten music/sound")

plt.legend()

plt.show()

# %%
f, (ax1, ax2, ax3) = plt.subplots(3, sharex=True , sharey=True)


f.suptitle('Pulsdaten')
ax1.plot(x)
ax2.plot(z, label="stress" )#scatter(z)
ax3.plot(y)#scatter(y, 2 * y ** 2 - 1, color='r')

ax3.set_xlabel('Zeit(s)', fontdict=None, labelpad=None)
ax2.set_ylabel('Puls(bpm)', fontdict=None, labelpad=None)

ax1.axvspan(0,154, facecolor='0.8',alpha = 0.5)
ax1.axvspan(182,330, facecolor='0.9',alpha = 0.5)
ax1.axvspan(358,506, facecolor='0.8',alpha = 0.5)
ax1.axvspan(534,682, facecolor='0.9',alpha = 0.5)

ax3.axvspan(0,154, facecolor='0.8',alpha = 0.5)
ax3.axvspan(182,330, facecolor='0.9',alpha = 0.5)
ax3.axvspan(358,506, facecolor='0.8',alpha = 0.5)
ax3.axvspan(534,682, facecolor='0.9',alpha = 0.5)

ax1.text(50.93, 30.34, s='Stress', )
#ax1.legend('Stress 1')
# Fine-tune figure; make subplots close to each other and hide x ticks for
# all but ottom plot.
f.subplots_adjust(hspace=0)
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

plt.show()
# Three subplots sharing both x/y axes

# %%
f
