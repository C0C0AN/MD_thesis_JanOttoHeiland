# %%
df = read.csv("stress_vs_relax.tsv", sep="\t");
df
# Out:
#       run trial  puls
# 1     1   relax   -4.75
# 2     1   relax   -2.91
# 3     1   relax    2.42
# 4     1   relax    2.45
# 5     1   relax   -5.28
# 6     1   relax    1.19
# 7     1   relax    2.80
# 8     1   relax    5.99
# 9     1   relax    7.75
# 10    1   relax    8.62
# 11    1   relax   -2.11
# 12    1   relax   -3.31
# 13    1   relax    5.14
# 14    1   relax    6.59
# 15    1   relax   -9.33
# 16    1   relax    9.53
# 17    1   relax   -0.86
# 18    1   relax    3.56
# 19    1   relax   -5.28
# 20    1   relax   -1.85
# 21    1   relax   16.05
# 22    1   relax    0.36
# 23    1   relax  -11.33
# 24    1   relax   -6.52
# 25    1   relax   -4.75
# 26    1   relax   -2.91
# 27    1   relax    2.42
# 28    1   relax    2.45
# 29    1   relax   -5.28
# 30    1   relax    1.19
# ⋮     ⋮   ⋮      ⋮
# 15667 2   stress  7.68
# 15668 2   stress  7.23
# 15669 2   stress  2.93
# 15670 2   stress  0.79
# 15671 2   stress 12.86
# 15672 2   stress  8.98
# 15673 2   stress  1.52
# ...

# %%
stress = df[df$trial == "stress",]
relax = df[df$trial == "relax",]

# %%
t.test(stress$puls, relax$puls)
# Out:
# 	Welch Two Sample t-test
#
# data:  stress$puls and relax$puls
# t = 74.878, df = 15387, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  5.544536 5.842623
# sample estimates:
# mean of x mean of y
#  3.318646 -2.374934
