# %%
# %matplotlib inline
from nilearn.plotting import plot_stat_map
from nilearn.plotting import plot_glass_brain

# %%
mask = "/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/fmriprep/mni_icbm152_nlin_asym_09c/1mm_T1.nii.gz"

# %%
relax_stress_stat = plot_stat_map(
    '/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/2ndLevel/ants_con_0004_fwhm4/spmT_0001_thr.nii', 
    title='relax>stress, FWE<0.05 cluster-corrected', dim=1, bg_img=mask, threshold=2, vmax=8, display_mode='z', 
    cut_coords=(10, 5, 0, -3), cmap='inferno')

# %%
relax_stress_glass = plot_glass_brain(
    '/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/2ndLevel/ants_con_0004_fwhm4/spmT_0001_thr.nii',
    colorbar=True, threshold=2, display_mode='lyrz', black_bg=True, vmax=8, 
    title='relax>stress, FWE<0.05 cluster-corrected', cmap='inferno');

# %%
stress_stat = plot_stat_map(
    '/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/2ndLevel/ants_con_0001_fwhm4/spmT_0001_thr.nii', 
    title='stress, FWE<0.05 cluster-corrected', dim=1, bg_img=mask, threshold=0, vmax=8, display_mode='z', 
    cut_coords=(10, 5, 0, -3), cmap='inferno')

# %%
stress_glass = plot_glass_brain(
    '/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/2ndLevel/ants_con_0001_fwhm4/spmT_0001_thr.nii',
    colorbar=True, threshold=3.5, display_mode='lyrz', black_bg=True, vmax=8, 
    title='stress, FWE<0.05 cluster-corrected', cmap='inferno');

# %%
stress_relax_stat = plot_stat_map(
    '/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/2ndLevel/ants_con_0003_fwhm4/spmT_0001_thr.nii', 
    title='stress>relax, FWE<0.05 cluster-corrected', dim=1, bg_img=mask, threshold=2, vmax=8, display_mode='z', 
    cut_coords=(10, 5, 0, -3), cmap='inferno')

# %%
stress_relax_glass = plot_glass_brain(
    '/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/2ndLevel/ants_con_0003_fwhm4/spmT_0001_thr.nii',
    colorbar=True, threshold=2, display_mode='lyrz', black_bg=True, vmax=8, 
    title='stress>relax, FWE<0.05 cluster-corrected', cmap='inferno');

# %%
relax_stat = plot_stat_map(
    '/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/2ndLevel/ants_con_0002_fwhm4/spmT_0001_thr.nii', 
    title='relax, FWE<0.05 cluster-corrected', dim=1, bg_img=mask, threshold=2, vmax=8, display_mode='z', 
    cut_coords=(10, 5, 0, -3), cmap='inferno')

# %%
relax_glass = plot_glass_brain(
    '/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/2ndLevel/ants_con_0002_fwhm4/spmT_0001_thr.nii',
    colorbar=True, threshold=2, display_mode='lyrz', black_bg=True, vmax=8, 
    title='relax, FWE<0.05 cluster-corrected', cmap='inferno');

# %%
stress_gremium_stat = plot_stat_map(
    '/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/2ndLevel/ants_con_0005_fwhm4/spmT_0001_thr.nii', 
    title='stress_gremium, FWE<0.05 cluster-corrected', dim=1, bg_img=mask, threshold=2, vmax=8, display_mode='z', 
    cut_coords=(10, 5, 0, -3), cmap='inferno')

# %%
stress_gremium_glass = plot_glass_brain(
    '/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/2ndLevel/ants_con_0005_fwhm4/spmT_0001_thr.nii',
    colorbar=True, threshold=2, display_mode='lyrz', black_bg=True, vmax=8, 
    title='stress_gremium, FWE<0.05 cluster-corrected', cmap='inferno');

# %% [markdown]
# Plot two sample t-test

# %%
musik_stress = plot_glass_brain(
    '/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/two_sample/datasink/2ndLevel/con_001/spmT_0001.nii',
    colorbar=True, threshold=5, display_mode='lyrz', black_bg=True, vmax=8, 
    title='musik_stress, FWE<0.05 cluster-corrected', cmap='inferno');

# %%
sound_stress = plot_glass_brain(
    '/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/two_sample/datasink/2ndLevel/con_001/spmT_0002.nii',
    colorbar=True, threshold=5, display_mode='lyrz', black_bg=True, vmax=8, 
    title='sound_stress, FWE<0.05 cluster-corrected', cmap='inferno');

# %%
musik_sound_stress = plot_glass_brain(
    '/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/two_sample/datasink/2ndLevel/con_001/spmT_0004.nii',
    colorbar=True, threshold=4, display_mode='lyrz', black_bg=True, vmax=8, 
    title='musik>sound_stress, FWE<0.05 cluster-corrected', cmap='inferno');

# %%
musik_relax = plot_glass_brain(
    '/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/two_sample/datasink/2ndLevel/con_002/spmT_0001.nii',
    colorbar=True, threshold=4.3, display_mode='lyrz', black_bg=True, vmax=8, 
    title='musik_relax, FWE<0.05 cluster-corrected', cmap='inferno');

# %%
sound_relax = plot_glass_brain(
    '/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/two_sample/datasink/2ndLevel/con_002/spmT_0002.nii',
    colorbar=True, threshold=4, display_mode='lyrz', black_bg=True, vmax=8, 
    title='sound_relax, FWE<0.05 cluster-corrected', cmap='inferno');

# %%
musik_sound_relax = plot_glass_brain(
    '/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/two_sample/datasink/2ndLevel/con_002/spmT_0004.nii',
    colorbar=True, threshold=3.6, display_mode='lyrz', black_bg=True, vmax=8, 
    title='musik>relax_relax, FWE<0.05 cluster-corrected', cmap='inferno');

# %%
musik_stress_relax = plot_glass_brain(
    '/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/two_sample/datasink/2ndLevel/con_003/spmT_0001.nii',
    colorbar=True, threshold=4, display_mode='lyrz', black_bg=True, vmax=8, 
    title='musik_stress>relax, FWE<0.05 cluster-corrected', cmap='inferno');

# %%
sound_stress_relax = plot_glass_brain(
    '/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/two_sample/datasink/2ndLevel/con_003/spmT_0002.nii',
    colorbar=True, threshold=3.5, display_mode='lyrz', black_bg=True, vmax=8, 
    title='sound_stress>relax, FWE<0.05 cluster-corrected', cmap='inferno');

# %%
musik_sound_stress_relax = plot_glass_brain(
    '/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/two_sample/datasink/2ndLevel/con_003/spmT_0004.nii',
    colorbar=True, threshold=3.5, display_mode='lyrz', black_bg=True, vmax=8, 
    title='musik>sound_stress>relax, FWE<0.05 cluster-corrected', cmap='inferno');

# %%
musik_relax_stress = plot_glass_brain(
    '/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/two_sample/datasink/2ndLevel/con_004/spmT_0001.nii',
    colorbar=True, threshold=4, display_mode='lyrz', black_bg=True, vmax=8, 
    title='musik_relax>stress, FWE<0.05 cluster-corrected', cmap='inferno');

# %%
sound_relax_stress = plot_glass_brain(
    '/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/two_sample/datasink/2ndLevel/con_004/spmT_0002.nii',
    colorbar=True, threshold=3.5, display_mode='lyrz', black_bg=True, vmax=8, 
    title='sound_relax>stress, FWE<0.05 cluster-corrected', cmap='inferno');

# %%
musik_sound_relax_stress = plot_glass_brain(
    '/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/two_sample/datasink/2ndLevel/con_004/spmT_0004.nii',
    colorbar=True, threshold=3.5, display_mode='lyrz', black_bg=True, vmax=8, 
    title='musik>sound_relax>stress, FWE<0.05 cluster-corrected', cmap='inferno');

# %%
musik_stress_gremium = plot_glass_brain(
    '/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/two_sample/datasink/2ndLevel/con_005/spmT_0001.nii',
    colorbar=True, threshold=4, display_mode='lyrz', black_bg=True, vmax=8, 
    title='musik_stress_gremium, FWE<0.05 cluster-corrected', cmap='inferno');

# %%
sound_stress_gremium = plot_glass_brain(
    '/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/two_sample/datasink/2ndLevel/con_005/spmT_0002.nii',
    colorbar=True, threshold=4, display_mode='lyrz', black_bg=True, vmax=8, 
    title='sound_stress_gremium, FWE<0.05 cluster-corrected', cmap='inferno');

# %%
musik_sound_stress_gremium = plot_glass_brain(
    '/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/two_sample/datasink/2ndLevel/con_005/spmT_0004.nii',
    colorbar=True, threshold=4, display_mode='lyrz', black_bg=True, vmax=8, 
    title='musik_sound_stress_gremium, FWE<0.05 cluster-corrected', cmap='inferno');

# %%
stress_stat.savefig('/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/2ndLevel/plot/stress_stat.pdf')
stress_glass.savefig('/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/2ndLevel/plot/stress_glass.pdf')
relax_stat.savefig('/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/2ndLevel/plot/relax_stat.pdf')
relax_glass.savefig('/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/2ndLevel/plot/relax_glass.pdf')
stress_relax_stat.savefig('/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/2ndLevel/plot/stress_relax_stat.pdf')
stress_relax_glass.savefig('/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/2ndLevel/plot/stress_relax_glass.pdf')
relax_stress_stat.savefig('/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/2ndLevel/plot/relax_stress_stat.pdf')
relax_stress_glass.savefig('/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/2ndLevel/plot/relax_stress_glass.pdf')
stress_gremium_stat.savefig('/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/2ndLevel/plot/stress_gremium_stat.pdf')
stress_gremium_glass.savefig('/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/2ndLevel/plot/stress_gremium_glass.pdf')

musik_stress.savefig('/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/2ndLevel/plot/musik_stress_glass.pdf')
sound_stress.savefig('/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/2ndLevel/plot/sound_stress_glass.pdf')
musik_sound_stress.savefig('/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/2ndLevel/plot/musik_sound_stress_glass.pdf')
musik_relax.savefig('/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/2ndLevel/plot/musik_relax_glass.pdf')
sound_relax.savefig('/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/2ndLevel/plot/sound_relax_glass.pdf')
musik_sound_relax.savefig('/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/2ndLevel/plot/musik_sound_relax_glass.pdf')
musik_stress_relax.savefig('/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/2ndLevel/plot/musik_stress>relax_glass.pdf')
sound_stress_relax.savefig('/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/2ndLevel/plot/sound_stress>relax_glass.pdf')
musik_sound_stress_relax.savefig('/media/lmn/86A406A0A406933B6/HOAF/HOAF_BIDS/derivatives/secondlevel/datasink/2ndLevel/plot/musik_sound_stress>relax_glass.pdf')
musik_relax
