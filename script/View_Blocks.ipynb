# %%
import pandas as pd

# %%
df = pd.read_csv('blocks.csv', index_col=0)

# %%
df
# Out:
#               1261.3976  1984.9446   2222.343  2742.8908  3077.9946  3801.5416
# HOAF_01.vhdr
# HOAF_02.vhdr  1073.0352  1796.5824  2032.0306  2552.5784  2854.1622  3577.7092
# HOAF_03.vhdr  1099.2034  1822.7506  2072.5336  2593.0814  2898.2656  3621.8126
# HOAF_04.vhdr   961.3774  1684.9244  1892.0698  2412.6176  2694.5830  3418.1300
# HOAF_05.vhdr  1065.1900  1788.7372  2046.7376  2567.2854  2842.1666  3565.7136
# HOAF_09.vhdr   773.0514  1496.6014  1695.7970  2216.3470  2469.0272  3192.5772
# HOAF_11.vhdr  1172.3928  1895.9428  2130.4258  2650.9758  2967.0626  3690.6126
# HOAF_12.vhdr  1124.1430  1847.6930  2040.1882  2560.7382  2874.4084  3597.9584
# HOAF_13.vhdr  1092.3838  1815.9338  2031.1648  2551.7148  3158.3484  3881.8984
# HOAF_14.vhdr  1131.0316  1854.5816  2041.5762  2562.1262  2884.8974  3608.4474
# HOAF_15.vhdr  1104.1136  1827.6636  2027.5262  2548.0762  2848.4450  3571.9950
# HOAF_16.vhdr  1366.5738  2090.1238  2324.4066  2844.9566  3195.8806  3919.4306
# ...

# %%
s0= df.iloc[:,0]

# %%
s0+6
# Out:
# HOAF_01.vhdr
# HOAF_02.vhdr    1079.0352
# HOAF_03.vhdr    1105.2034
# HOAF_04.vhdr     967.3774
# HOAF_05.vhdr    1071.1900
# HOAF_09.vhdr     779.0514
# HOAF_11.vhdr    1178.3928
# HOAF_12.vhdr    1130.1430
# HOAF_13.vhdr    1098.3838
# HOAF_14.vhdr    1137.0316
# HOAF_15.vhdr    1110.1136
# HOAF_16.vhdr    1372.5738
# HOAF_17.vhdr    1096.3768
# HOAF_19.vhdr    1342.3236
# HOAF_20.vhdr    1125.4254
# HOAF_21.vhdr    1166.4924
# HOAF_22.vhdr    1218.7706
# HOAF_23.vhdr    1026.0732
# HOAF_24.vhdr    1336.8764
# HOAF_25.vhdr    1247.5186
# HOAF_26.vhdr    1327.1064
# HOAF_27.vhdr    1240.7980
# HOAF_28.vhdr    1315.3614
# HOAF_29.vhdr    1201.9162
# Name: 1261.3976, dtype: float64

# %%
s0+154
# Out:
# HOAF_01.vhdr
# HOAF_02.vhdr    1227.0352
# HOAF_03.vhdr    1253.2034
# HOAF_04.vhdr    1115.3774
# HOAF_05.vhdr    1219.1900
# HOAF_09.vhdr     927.0514
# HOAF_11.vhdr    1326.3928
# HOAF_12.vhdr    1278.1430
# HOAF_13.vhdr    1246.3838
# HOAF_14.vhdr    1285.0316
# HOAF_15.vhdr    1258.1136
# HOAF_16.vhdr    1520.5738
# HOAF_17.vhdr    1244.3768
# HOAF_19.vhdr    1490.3236
# HOAF_20.vhdr    1273.4254
# HOAF_21.vhdr    1314.4924
# HOAF_22.vhdr    1366.7706
# HOAF_23.vhdr    1174.0732
# HOAF_24.vhdr    1484.8764
# HOAF_25.vhdr    1395.5186
# HOAF_26.vhdr    1475.1064
# HOAF_27.vhdr    1388.7980
# HOAF_28.vhdr    1463.3614
# HOAF_29.vhdr    1349.9162
# Name: 1261.3976, dtype: float64

# %%
s0+182
# Out:
# HOAF_01.vhdr
# HOAF_02.vhdr    1255.0352
# HOAF_03.vhdr    1281.2034
# HOAF_04.vhdr    1143.3774
# HOAF_05.vhdr    1247.1900
# HOAF_09.vhdr     955.0514
# HOAF_11.vhdr    1354.3928
# HOAF_12.vhdr    1306.1430
# HOAF_13.vhdr    1274.3838
# HOAF_14.vhdr    1313.0316
# HOAF_15.vhdr    1286.1136
# HOAF_16.vhdr    1548.5738
# HOAF_17.vhdr    1272.3768
# HOAF_19.vhdr    1518.3236
# HOAF_20.vhdr    1301.4254
# HOAF_21.vhdr    1342.4924
# HOAF_22.vhdr    1394.7706
# HOAF_23.vhdr    1202.0732
# HOAF_24.vhdr    1512.8764
# HOAF_25.vhdr    1423.5186
# HOAF_26.vhdr    1503.1064
# HOAF_27.vhdr    1416.7980
# HOAF_28.vhdr    1491.3614
# HOAF_29.vhdr    1377.9162
# Name: 1261.3976, dtype: float64

# %%
s0+330
# Out:
# HOAF_01.vhdr
# HOAF_02.vhdr    1403.0352
# HOAF_03.vhdr    1429.2034
# HOAF_04.vhdr    1291.3774
# HOAF_05.vhdr    1395.1900
# HOAF_09.vhdr    1103.0514
# HOAF_11.vhdr    1502.3928
# HOAF_12.vhdr    1454.1430
# HOAF_13.vhdr    1422.3838
# HOAF_14.vhdr    1461.0316
# HOAF_15.vhdr    1434.1136
# HOAF_16.vhdr    1696.5738
# HOAF_17.vhdr    1420.3768
# HOAF_19.vhdr    1666.3236
# HOAF_20.vhdr    1449.4254
# HOAF_21.vhdr    1490.4924
# HOAF_22.vhdr    1542.7706
# HOAF_23.vhdr    1350.0732
# HOAF_24.vhdr    1660.8764
# HOAF_25.vhdr    1571.5186
# HOAF_26.vhdr    1651.1064
# HOAF_27.vhdr    1564.7980
# HOAF_28.vhdr    1639.3614
# HOAF_29.vhdr    1525.9162
# Name: 1261.3976, dtype: float64

# %%
s0+358
# Out:
# HOAF_01.vhdr
# HOAF_02.vhdr    1431.0352
# HOAF_03.vhdr    1457.2034
# HOAF_04.vhdr    1319.3774
# HOAF_05.vhdr    1423.1900
# HOAF_09.vhdr    1131.0514
# HOAF_11.vhdr    1530.3928
# HOAF_12.vhdr    1482.1430
# HOAF_13.vhdr    1450.3838
# HOAF_14.vhdr    1489.0316
# HOAF_15.vhdr    1462.1136
# HOAF_16.vhdr    1724.5738
# HOAF_17.vhdr    1448.3768
# HOAF_19.vhdr    1694.3236
# HOAF_20.vhdr    1477.4254
# HOAF_21.vhdr    1518.4924
# HOAF_22.vhdr    1570.7706
# HOAF_23.vhdr    1378.0732
# HOAF_24.vhdr    1688.8764
# HOAF_25.vhdr    1599.5186
# HOAF_26.vhdr    1679.1064
# HOAF_27.vhdr    1592.7980
# HOAF_28.vhdr    1667.3614
# HOAF_29.vhdr    1553.9162
# Name: 1261.3976, dtype: float64

# %%
s0+506
# Out:
# HOAF_01.vhdr
# HOAF_02.vhdr    1579.0352
# HOAF_03.vhdr    1605.2034
# HOAF_04.vhdr    1467.3774
# HOAF_05.vhdr    1571.1900
# HOAF_09.vhdr    1279.0514
# HOAF_11.vhdr    1678.3928
# HOAF_12.vhdr    1630.1430
# HOAF_13.vhdr    1598.3838
# HOAF_14.vhdr    1637.0316
# HOAF_15.vhdr    1610.1136
# HOAF_16.vhdr    1872.5738
# HOAF_17.vhdr    1596.3768
# HOAF_19.vhdr    1842.3236
# HOAF_20.vhdr    1625.4254
# HOAF_21.vhdr    1666.4924
# HOAF_22.vhdr    1718.7706
# HOAF_23.vhdr    1526.0732
# HOAF_24.vhdr    1836.8764
# HOAF_25.vhdr    1747.5186
# HOAF_26.vhdr    1827.1064
# HOAF_27.vhdr    1740.7980
# HOAF_28.vhdr    1815.3614
# HOAF_29.vhdr    1701.9162
# Name: 1261.3976, dtype: float64

# %%
s0+534
# Out:
# HOAF_01.vhdr
# HOAF_02.vhdr    1607.0352
# HOAF_03.vhdr    1633.2034
# HOAF_04.vhdr    1495.3774
# HOAF_05.vhdr    1599.1900
# HOAF_09.vhdr    1307.0514
# HOAF_11.vhdr    1706.3928
# HOAF_12.vhdr    1658.1430
# HOAF_13.vhdr    1626.3838
# HOAF_14.vhdr    1665.0316
# HOAF_15.vhdr    1638.1136
# HOAF_16.vhdr    1900.5738
# HOAF_17.vhdr    1624.3768
# HOAF_19.vhdr    1870.3236
# HOAF_20.vhdr    1653.4254
# HOAF_21.vhdr    1694.4924
# HOAF_22.vhdr    1746.7706
# HOAF_23.vhdr    1554.0732
# HOAF_24.vhdr    1864.8764
# HOAF_25.vhdr    1775.5186
# HOAF_26.vhdr    1855.1064
# HOAF_27.vhdr    1768.7980
# HOAF_28.vhdr    1843.3614
# HOAF_29.vhdr    1729.9162
# Name: 1261.3976, dtype: float64

# %%
s0+682
# Out:
# HOAF_01.vhdr
# HOAF_02.vhdr    1755.0352
# HOAF_03.vhdr    1781.2034
# HOAF_04.vhdr    1643.3774
# HOAF_05.vhdr    1747.1900
# HOAF_09.vhdr    1455.0514
# HOAF_11.vhdr    1854.3928
# HOAF_12.vhdr    1806.1430
# HOAF_13.vhdr    1774.3838
# HOAF_14.vhdr    1813.0316
# HOAF_15.vhdr    1786.1136
# HOAF_16.vhdr    2048.5738
# HOAF_17.vhdr    1772.3768
# HOAF_19.vhdr    2018.3236
# HOAF_20.vhdr    1801.4254
# HOAF_21.vhdr    1842.4924
# HOAF_22.vhdr    1894.7706
# HOAF_23.vhdr    1702.0732
# HOAF_24.vhdr    2012.8764
# HOAF_25.vhdr    1923.5186
# HOAF_26.vhdr    2003.1064
# HOAF_27.vhdr    1916.7980
# HOAF_28.vhdr    1991.3614
# HOAF_29.vhdr    1877.9162
# Name: 1261.3976, dtype: float64
